# %% [markdown]
# # 統計の基礎的な学習
#
# ## データのダウンロード
# SSDSE（教育用標準データセット）: https://www.nstac.go.jp/SSDSE/
#
# C. 都道府県庁所在市別・家計消費データ
# をこのファイルと同じ階層に保存する。

# %%
# import packages 
import numpy as np
import scipy as sp
import pandas as pd

# %%
# load csv file
data = pd.read_csv('./SSDSE-2020C.csv', encoding='cp932')

# %%
data.head(5)
# Out:
#   2017_2019 Prefecture City  LA03    LB00   LB01 LB011001 LB012001 LB012002  \
# 0     地域コード       都道府県    市  世帯人員  食料（合計）  01　穀類        米      食パン     他のパン
# 1    R00000         全国   全国  2.98  954715  77480    23736     9461    21430
# 2    R01100        北海道  札幌市  2.96  910399  81474    30994     8496    18942
# 3    R02201        青森県  青森市  2.98  878930  71992    23773     7777    17336
# 4    R03201        岩手県  盛岡市  3.15  951176  80203    25867     8270    20622
#
#   LB013001  ... LB121104 LB121105 LB121106 LB121107 LB121108 LB121109  \
# 0  生うどん・そば  ...   すし（外食）       和食      中華食       洋食       焼肉   ハンバーガー
# 1     3322  ...    14885    23048     4838    12927     7082     4141
# 2     2973  ...    19850    23858     4510    17165     7681     3688
# 3     2777  ...    13293    15006     3560     9825     7356     3107
# 4     3198  ...    13807     9810     2012     6563     6897     3244
#
#   LB121110 LB121201 LB121202 LB122001
# 0  他の主食的外食      喫茶代      飲酒代     学校給食
# ...
